# %%
import numpy as np

# %%
student_score = [
[1, 90, 80, 85, 0, 0.0, 0, 0],
[2, 90, 87, 90, 0, 0.0, 0, 0],
[3, 80, 80, 80, 0, 0.0, 0, 0],
[4, 42, 75, 93, 0, 0.0, 0, 0],
[5, 85, 87, 86, 0, 0.0, 0, 0]
]

# %%
student = np.array(student_score)

# %%
student.shape
# Out:
# (5, 8)

# %%
# 총점, 평균, min, max 
student[:, 4] = np.sum(student[:,1:4],axis=1)
student[:, 5] = np.mean(student[:,1:4],axis=1)
student[:, 6] = np.min(student[:,1:4],axis=1)
student[:, 7] = np.max(student[:,1:4],axis=1)

# %%
student
# Out:
# array([[  1.,  90.,  80.,  85., 255.,  85.,  80.,  90.],
#        [  2.,  90.,  87.,  90., 267.,  89.,  87.,  90.],
#        [  3.,  80.,  80.,  80., 240.,  80.,  80.,  80.],
#        [  4.,  42.,  75.,  93., 210.,  70.,  42.,  93.],
#        [  5.,  85.,  87.,  86., 258.,  86.,  85.,  87.]])

# %%
class_avg = np.mean(student[:,5],axis=0)
class_avg
# Out:
# 82.0

# %%
# 과목별 평균
sub_avg = student[:, 1:4].mean(axis=0)
for i in sub_avg:
  print(""i)
# Out:
# 77.4
# 81.8
# 86.8

# %%
students_score = [
{'num':'1', 'name':'김철수','kor':90, 'eng':80, 'math':85},
{'num':'2', 'name':'박제동','kor':90, 'eng':85, 'math':90},
{'num':'3', 'name':'홍길동','kor':80, 'eng':80, 'math':80}
]

# %%
# 전처리

student_score = []
for i in students_score:
  # print(i)
  st = [int(i['num']), i['kor'], i['eng'], i['math'], 0, 0.0, 0, 0]
  # print(st)
  student_score += [st]
student_score
# Out:
# [[1, 90, 80, 85, 0, 0.0, 0, 0],
#  [2, 90, 85, 90, 0, 0.0, 0, 0],
#  [3, 80, 80, 80, 0, 0.0, 0, 0]]

# %%
student_score[0][0]
# Out:
# 1
