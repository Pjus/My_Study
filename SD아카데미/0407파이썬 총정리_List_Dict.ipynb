# %%
# 리스트는 값 가져올때 숫자 행 열
student_score = [
 [1, 90, 80, 85, 0, 0.0, 0],
 [2, 90, 85, 90, 0, 0.0, 0],
 [3, 80, 80, 80, 0, 0.0, 0]
]

# %%
# 딕트는 값 가져올때 키 벨류
a = [
{'num':'1', 'name':'김철수','kor':90, 'eng':80, 'math':85, 'total':0, 'avg':0.0, 'order':0 },
{'num':'2', 'name':'박제동','kor':90, 'eng':85, 'math':90, 'total':0, 'avg':0.0, 'order':0 },
{'num':'3', 'name':'홍길동','kor':80,' eng':80, 'math':80, 'total':0, 'avg':0.0, 'order':0 }
]

# %%
student_score
# Out:
# [[1, 90, 80, 85, 0, 0.0, 0],
#  [2, 90, 85, 90, 0, 0.0, 0],
#  [3, 80, 80, 80, 0, 0.0, 0]]

# %%
a

# %%
student_score[1] = [1,98,80,50,0,0,0]

# %%
student_score
# Out:
# [[1, 90, 80, 85, 0, 0.0, 0],
#  [1, 98, 80, 50, 0, 0, 0],
#  [3, 80, 80, 80, 0, 0.0, 0]]

# %%
a[2] = {'num' : 232, 'name' : 'ahah', 'kor' : 5, 'eng' : 8, 'math' : 5, 'total' : 0, 'avg' : 0, 'order' : 0}

# %%
a[2]
# Out:
# {'avg': 0,
#  'eng': 8,
#  'kor': 5,
#  'math': 5,
#  'name': 'ahah',
#  'num': 232,
#  'order': 0,
#  'total': 0}

# %%
student_score[0][1] = 92

# %%
student_score
# Out:
# [[1, 92, 80, 85, 0, 0.0, 0],
#  [1, 98, 80, 50, 0, 0, 0],
#  [3, 80, 80, 80, 0, 0.0, 0]]

# %%
a[2]['name'] = '홍길동'

# %%
a
# Out:
# [{'avg': 0.0,
#   'eng': 80,
#   'kor': 90,
#   'math': 85,
#   'name': '김철수',
#   'num': '1',
#   'order': 0,
#   'total': 0},
#  {'avg': 0.0,
#   'eng': 85,
#   'kor': 90,
#   'math': 90,
#   'name': '박제동',
#   'num': '2',
#   'order': 0,
#   'total': 0},
#  {'avg': 0,
#   'eng': 8,
#   'kor': 5,
#   'math': 5,
#   'name': '홍길동',
#   'num': 232,
#   'order': 0,
#   'total': 0}]

# %%
del student_score[0][1]

# %%
student_score
# Out:
# [[1, 80, 85, 0, 0.0, 0],
#  [2, 90, 85, 90, 0, 0.0, 0],
#  [3, 80, 80, 80, 0, 0.0, 0]]

# %%
del a[0]['name']

# %%
a

# %%
a[0]['name'] = '김철수'

# %%
student_score.insert(0, [65,1,5,2,65])

# %%
student_score
# Out:
# [[65, 1, 5, 2, 65],
#  [1, 80, 85, 0, 0.0, 0],
#  [2, 90, 85, 90, 0, 0.0, 0],
#  [3, 80, 80, 80, 0, 0.0, 0]]

# %%
a.insert(len(a), {'num':0, 'name':'aja', 'kor':54})

# %%
a
# Out:
# [{'avg': 0.0,
#   'eng': 80,
#   'kor': 90,
#   'math': 85,
#   'num': '1',
#   'order': 0,
#   'total': 0},
#  {'avg': 0.0,
#   'eng': 85,
#   'kor': 90,
#   'math': 90,
#   'name': '박제동',
#   'num': '2',
#   'order': 0,
#   'total': 0},
#  {'avg': 0,
#   'eng': 8,
#   'kor': 5,
#   'math': 5,
#   'name': '홍길동',
#   'num': 232,
#   'order': 0,
#   'total': 0},
#  {'kor': 54, 'name': 'aja', 'num': 0}]

# %%
student_score[0].insert(0,111)

# %%
student_score
# Out:
# [[111, 65, 1, 5, 2, 65],
#  [1, 80, 85, 0, 0.0, 0],
#  [2, 90, 85, 90, 0, 0.0, 0],
#  [3, 80, 80, 80, 0, 0.0, 0]]

# %%
a[3]['kor']=50

# %%
a
# Out:
# [{'avg': 0.0,
#   'eng': 80,
#   'kor': 90,
#   'math': 85,
#   'num': '1',
#   'order': 0,
#   'total': 0},
#  {'avg': 0.0,
#   'eng': 85,
#   'kor': 90,
#   'math': 90,
#   'name': '박제동',
#   'num': '2',
#   'order': 0,
#   'total': 0},
#  {'avg': 0,
#   'eng': 8,
#   'kor': 5,
#   'math': 5,
#   'name': '홍길동',
#   'num': 232,
#   'order': 0,
#   'total': 0},
#  {'kor': 50, 'name': 'aja', 'num': 0}]

# %%
for item in student_score:
  print(item, type(item))
# Out:
# [111, 65, 1, 5, 2, 65] <class 'list'>
# [1, 80, 85, 0, 0.0, 0] <class 'list'>
# [2, 90, 85, 90, 0, 0.0, 0] <class 'list'>
# [3, 80, 80, 80, 0, 0.0, 0] <class 'list'>

# %%
for item in a:
  print(item, type(item))
# Out:
# {'num': '1', 'kor': 90, 'eng': 80, 'math': 85, 'total': 0, 'avg': 0.0, 'order': 0} <class 'dict'>fff
# {'num': '2', 'name': '박제동', 'kor': 90, 'eng': 85, 'math': 90, 'total': 0, 'avg': 0.0, 'order': 0} <class 'dict'>fff
# {'num': 232, 'name': '홍길동', 'kor': 5, 'eng': 8, 'math': 5, 'total': 0, 'avg': 0, 'order': 0} <class 'dict'>fff
# {'num': 0, 'name': 'aja', 'kor': 50} <class 'dict'>fff
