# %%
movies = ["The Holy Grail", "The Life of Brian", "The Meaning of Life"]

# %%
for i in movies:
  print(i)
# Out:
# The Holy Grail
# The Life of Brian
# The Meaning of Life

# %%
def print_list(list_1):
  for i in list_1:
    print(i)
  return

# %%
print_list(movies)
# Out:
# The Holy Grail
# The Life of Brian
# The Meaning of Life
