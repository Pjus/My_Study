# %%
# 변수 함수 오브젝트

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib
# Out:
# Using matplotlib backend: agg

# %%
df1 = pd.DataFrame(np.random.rand(100,3))

# %%
df1.tail()
# Out:
#            0         1         2
# 95  0.493599  0.454949  0.062536
# 96  0.833164  0.309299  0.181868
# 97  0.963774  0.106327  0.861284
# 98  0.770161  0.897235  0.705844
# 99  0.230040  0.470283  0.032551

# %%
df1.plot()
plt.show()

# %%
len(df1)
# Out:
# 100

# %%
df1[:10]
# Out:
#           0         1         2
# 0  0.269380  0.325457  0.558939
# 1  0.325493  0.195823  0.663542
# 2  0.639446  0.226283  0.654804
# 3  0.090128  0.091442  0.583700
# 4  0.511370  0.929239  0.645189
# 5  0.033732  0.171064  0.821657
# 6  0.546842  0.196610  0.575831
# 7  0.298495  0.355016  0.361694
# 8  0.271675  0.161723  0.527112
# 9  0.491863  0.282107  0.479028

# %%
df1[1]
# Out:
# 0     0.325457
# 1     0.195823
# 2     0.226283
# 3     0.091442
# 4     0.929239
#         ...
# 95    0.454949
# 96    0.309299
# 97    0.106327
# 98    0.897235
# 99    0.470283
# Name: 1, Length: 100, dtype: float64

# %%
df1.describe()
# Out:
#                 0           1           2
# count  100.000000  100.000000  100.000000
# mean     0.496125    0.464260    0.489750
# std      0.277797    0.300731    0.273677
# min      0.001178    0.003006    0.000980
# 25%      0.254480    0.180069    0.275386
# 50%      0.522286    0.427276    0.525352
# 75%      0.731603    0.751200    0.689624
# max      0.998237    0.997539    0.967877

# %%
obj1 = pd.Series([4,5,-2], index=['a', 'b', 'c'])

# %%
obj1
# Out:
# a    4
# b    5
# c   -2
# dtype: int64

# %%
obj1.values
# Out:
# array([ 4,  5, -2])

# %%
obj1.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
obj1.dtypes
# Out:
# dtype('int64')

# %%
obj1.shape
# Out:
# (3,)

# %%
type(obj1)
# Out:
# pandas.core.series.Series

# %%
data = {'Name' : ['Tom', 'Jack', 'Steve', 'Ricky'], 'Age' : [28, 34, 29, 42]}

# %%
df01 = pd.DataFrame(data, index=['rank1', 'rank2', 'rank3', 'rank4'])

# %%
df01
# Out:
#         Name  Age
# rank1    Tom   28
# rank2   Jack   34
# rank3  Steve   29
# rank4  Ricky   42

# %%
df01.values
# Out:
# array([['Tom', 28],
#        ['Jack', 34],
#        ['Steve', 29],
#        ['Ricky', 42]], dtype=object)

# %%
df01.index
# Out:
# Index(['rank1', 'rank2', 'rank3', 'rank4'], dtype='object')

# %%
df01.columns
# Out:
# Index(['Name', 'Age'], dtype='object')

# %%
df01.dtypes
# Out:
# Name    object
# Age      int64
# dtype: object

# %%
type(df01)
# Out:
# pandas.core.frame.DataFrame

# %%
df01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, rank1 to rank4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 256.0+ bytes

# %%
df01.describe()
# Out:
#              Age
# count   4.000000
# mean   33.250000
# std     6.396614
# min    28.000000
# 25%    28.750000
# 50%    31.500000
# 75%    36.000000
# max    42.000000

# %%
df1 = pd.read_json('./input.json')

# %%
df1
# Out:
#    ID      Name  Salary   StartDate        Dept
# 0   1      Rick  623.30    1/1/2012          IT
# 1   2       Dan  515.20   9/23/2013  Operations
# 2   3  Michelle  611.00  11/15/2014          IT
# 3   4      Ryan  729.00   5/11/2014          HR
# 4   5      Gary  843.25   3/27/2015     Finance
# 5   6      Nina  578.00   5/21/2013          IT
# 6   7     Simon  632.80   7/30/2013  Operations
# 7   8      Guru  722.50   6/17/2014     Finance

# %%
df2 = pd.read_excel('input.xlsx')

# %%
df2
# Out:
#    id    name  zipcode
# 0   1    Rick   301224
# 1   2     Dan   341255
# 2   3   Tusar   297704
# 3   4    Ryan   216650
# 4   5    Gary   438700
# 5   6   Rasmi   665100
# 6   7  Pranab   341211
# 7   8    Guru   347480

# %%
# 파일 엑셀로 저장
df2.to_excel(r'./ouput.xlsx', index=True, header=True)

# %%
with pd.ExcelFile('input.xlsx') as xls:
  df3 = pd.read_excel(xls, 'Sheet2')

# %%
df3
# Out:
#    id    name  salary start_date        dept
# 0   1    Rick  623.30 2012-01-01          IT
# 1   2     Dan  515.20 2013-09-23  Operations
# 2   3   Tusar  611.00 2014-11-15          IT
# 3   4    Ryan  729.00 2014-05-11          HR
# 4   5    Gary  843.25 2015-03-27     Finance
# 5   6   Rasmi  578.00 2013-05-21          IT
# 6   7  Pranab  632.80 2013-07-30  Operations
# 7   8    Guru  722.50 2014-06-17     Finance

# %%
with pd.ExcelFile('input.xlsx') as xls:
  df4 = pd.read_excel(xls, 'Sheet1')

# %%
df4
# Out:
#    id    name  zipcode
# 0   1    Rick   301224
# 1   2     Dan   341255
# 2   3   Tusar   297704
# 3   4    Ryan   216650
# 4   5    Gary   438700
# 5   6   Rasmi   665100
# 6   7  Pranab   341211
# 7   8    Guru   347480

# %%
# !pip install sqlalchemy

# %%
from sqlalchemy import create_engine

# %%
data = pd.read_excel('input.csv')

# %%
data
# Out:
#    id    name  salary start_date        dept
# 0   1    Rick  623.30 2012-01-01          IT
# 1   2     Dan  515.20 2013-09-23  Operations
# 2   3   Tusar  611.00 2014-11-15          IT
# 3   4    Ryan  729.00 2014-05-11          HR
# 4   5    Gary  843.25 2015-03-27     Finance
# 5   6   Rasmi  578.00 2013-05-21          IT
# 6   7  Pranab  632.80 2013-07-30  Operations
# 7   8    Guru  722.50 2014-06-17     Finance

# %%
engine = create_engine('sqlite:///:memoty:')

# %%
data.to_sql('data_table', engine)

# %%
df4.to_sql('data_table1', engine)

# %%
res1 = pd.read_sql_query('SELECT*FROM data_table', engine)

# %%
res1
# Out:
#    index  id    name  salary                  start_date        dept
# 0      0   1    Rick  623.30  2012-01-01 00:00:00.000000          IT
# 1      1   2     Dan  515.20  2013-09-23 00:00:00.000000  Operations
# 2      2   3   Tusar  611.00  2014-11-15 00:00:00.000000          IT
# 3      3   4    Ryan  729.00  2014-05-11 00:00:00.000000          HR
# 4      4   5    Gary  843.25  2015-03-27 00:00:00.000000     Finance
# 5      5   6   Rasmi  578.00  2013-05-21 00:00:00.000000          IT
# 6      6   7  Pranab  632.80  2013-07-30 00:00:00.000000  Operations
# 7      7   8    Guru  722.50  2014-06-17 00:00:00.000000     Finance

# %%
res2 = pd.read_sql_query('SELECT*FROM data_table group by dept', engine)

# %%
res2
# Out:
#    index  id    name  salary                  start_date        dept
# 0      7   8    Guru   722.5  2014-06-17 00:00:00.000000     Finance
# 1      3   4    Ryan   729.0  2014-05-11 00:00:00.000000          HR
# 2      5   6   Rasmi   578.0  2013-05-21 00:00:00.000000          IT
# 3      6   7  Pranab   632.8  2013-07-30 00:00:00.000000  Operations

# %%
res3 = pd.read_sql_query('SELECT*FROM data_table group by salary', engine)

# %%
res3
# Out:
#    index  id    name  salary                  start_date        dept
# 0      1   2     Dan  515.20  2013-09-23 00:00:00.000000  Operations
# 1      5   6   Rasmi  578.00  2013-05-21 00:00:00.000000          IT
# 2      2   3   Tusar  611.00  2014-11-15 00:00:00.000000          IT
# 3      0   1    Rick  623.30  2012-01-01 00:00:00.000000          IT
# 4      6   7  Pranab  632.80  2013-07-30 00:00:00.000000  Operations
# 5      7   8    Guru  722.50  2014-06-17 00:00:00.000000     Finance
# 6      3   4    Ryan  729.00  2014-05-11 00:00:00.000000          HR
# 7      4   5    Gary  843.25  2015-03-27 00:00:00.000000     Finance

# %%
from collections import Counter

# %%
with open(r'./sample_data/README.md') as f:
  p_dict = Counter(f.read().split())

# %%
p_dict

# %%
res1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       8 non-null      int64
#  1   id          8 non-null      int64
#  2   name        8 non-null      object
#  3   salary      8 non-null      float64
#  4   start_date  8 non-null      object
#  5   dept        8 non-null      object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 512.0+ bytes

# %%
res1.describe(include='all')
# Out:
#           index       id   name      salary                  start_date dept
# count   8.00000  8.00000      8    8.000000                           8    8
# unique      NaN      NaN      8         NaN                           8    4
# top         NaN      NaN  Rasmi         NaN  2013-05-21 00:00:00.000000   IT
# freq        NaN      NaN      1         NaN                           1    3
# mean    3.50000  4.50000    NaN  656.881250                         NaN  NaN
# std     2.44949  2.44949    NaN  103.059463                         NaN  NaN
# min     0.00000  1.00000    NaN  515.200000                         NaN  NaN
# 25%     1.75000  2.75000    NaN  602.750000                         NaN  NaN
# 50%     3.50000  4.50000    NaN  628.050000                         NaN  NaN
# 75%     5.25000  6.25000    NaN  724.125000                         NaN  NaN
# max     7.00000  8.00000    NaN  843.250000                         NaN  NaN
