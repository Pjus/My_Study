# %%
print('Welcome to SD')
# Out:
# Welcome to SD

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
strr='Hello, World!'

# %%
print(strr)
# Out:
# Hello, World!

# %%
strr = 'Welcome to World!'

# %%
print(strr)
# Out:
# Welcome to World!

# %%
# 주석은 반드시 달기
# Tab, :

# %%
myage = input('what is your age?')
age = int(myage)
# Out:
# what is your age?27

# %%
print("Your age is " + str(age))
# Out:
# Your age is 27

# %%
string = "Hello World"

# %%
string[-3]
# Out:
# 'r'

# %%
string[2:5] #뒤에번호 값은 빠짐
# Out:
# 'llo'

# %%
string[2:]
# Out:
# 'llo World'

# %%
string.index('d')
# Out:
# 10

# %%
list1 = ['abcd', 786, 2.23, 'john', 70.2]
tinylist = [123, 'john']

# %%
list1
# Out:
# ['abcd', 786, 2.23, 'john', 70.2]

# %%
list1[0]
# Out:
# 'abcd'

# %%
list1[1:3]
# Out:
# [786, 2.23]

# %%
tinylist * 2
# Out:
# [123, 'john', 123, 'john']

# %%
list1 + tinylist
# Out:
# ['abcd', 786, 2.23, 'john', 70.2, 123, 'john']

# %%
list1[1] + tinylist[0]
# Out:
# 909

# %%
animal = ['Dog', 'Cat', 'Cow']

# %%
animal[2]
# Out:
# 'Cow'

# %%
animal
# Out:
# ['Dog', 'Cat', 'Cow']

# %%
animal[1] = 'Lion'

# %%
animal[2] = 'Cat'

# %%
animal
# Out:
# ['Dog', 'Lion', 'Cat']

# %%
del animal[2]

# %%
animal
# Out:
# ['Dog', 'Lion']
