# %% [markdown]
# 자료구조
#
# 변수 : BOX - 정수, 실수 , 문자, 문자열
#
# (벡터)
#
# 배열
#
# > 1차원 - 같은 크기의 변수가 나열
#
# > 2차원 - 표의 형식으로 변수 나열
#
# > 3차원(보편적 사용x)
#
# 리스트:

# %%
a = "*"
for i in range(5):
  print(a)
  a = a + "*"
# Out:
# *
# **
# ***
# ****
# *****

# %%
ex = [i for i in range(5)]

# %%
ex
# Out:
# [0, 1, 2, 3, 4]

# %%
ex[-5]
# Out:
# 0
