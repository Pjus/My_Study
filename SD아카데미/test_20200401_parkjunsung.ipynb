# %%
b = '20010331Rainy'
print(b[:8])
# Out:
# 20010331

# %%
print(b[:-5])
# Out:
# 20010331

# %%
print(b[:0])

# %%
print(b[:-1])
# Out:
# 20010331Rain

# %%
a = 'this is a string'

# %%
c = a.replace('string', 'rope') # 변수 값을 바꾸지 않으면 자기자신은 변화 없음
c, a
# Out:
# ('this is a rope', 'this is a rope')

# %%
a = 'Korean culture'

# %%
a.count('ul')
# Out:
# 1

# %%
a.count('e') # 몇개 있는지
# Out:
# 2

# %%
a.find('u') # 위치 값
# Out:
# 8

# %%
a.find('ul') # 위치 값
# Out:
# 8

# %%
a.find('e') # 위치 값, 첫번째 걸리는 것만 나옴
# Out:
# 3

# %%
a.find('k') # 없는 값이면 -1 나옴
# Out:
# -1

# %%
','.join('Korean culture')
# Out:
# 'K,o,r,e,a,n, ,c,u,l,t,u,r,e'

# %%
b = '   Korean culture    '

# %%
b.strip()
# Out:
# 'Korean culture'

# %%
# 리스트로 반환
c = 'Korean & American & China'
c.split('&')
# Out:
# ['Korean ', ' American ', ' China']
