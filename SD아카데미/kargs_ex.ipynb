# %%
def example(**kagrs):
  if 'kor' in kagrs:
    print('name : {}, kor_score : {}'.format(kagrs['name'], kagrs['kor']))
  if 'eng' in kagrs:
    print('name : {}, eng_score : {}'.format(kagrs['name'], kagrs['eng']))
  if 'math' in kagrs:
    print('name : {}, math_score : {}'.format(kagrs['name'], kagrs['math']))  
  if 'avg' in kagrs:
    print('name : {}, avg_score : {}'.format(kagrs['name'], kagrs['avg']))
    print('\n')

# %%
for i in students_score:
  example(**i)
