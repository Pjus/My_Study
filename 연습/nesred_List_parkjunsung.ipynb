# %%
movies = ['The Holy Grail', 1975, 'The Life of Brain', 91, ['Graham Cahpman', ['Michael Palin', 'John Cleese', 'Terry Gillam', 'Eric Idle']]]

# %%
movies
# Out:
# ['The Holy Grail',
#  1975,
#  'The Life of Brain',
#  91,
#  ['Graham Cahpman',
#   ['Michael Palin', 'John Cleese', 'Terry Gillam', 'Eric Idle']]]

# %%
isinstance(movies, list)
# Out:
# True

# %%
for movie in movies:
  if isinstance(movie, list):
    for i in movie:
      if isinstance(i, list):
        for j in i:
          print(j)
      else:
          print(i)
  else:
    print(movie)
# Out:
# 0 The Holy Grail
# 1 1975
# 2 The Life of Brain
# 3 91
# 4 Graham Cahpman
# 4 Michael Palin
# 4 John Cleese
# 4 Terry Gillam
# 4 Eric Idle
