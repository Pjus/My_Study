# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'http://media.daum.net/economic/'

# %%
res = requests.get(url)

# %%
type(res), res
# Out:
# (requests.models.Response, <Response [200]>)

# %%
res.status_code, res.content # res.status_code 200 아니면 정보 못가져옴 if문으로 거름
# Out:
# (200,
# ...

# %%
soup = BeautifulSoup(res.content, 'html.parser')

# %%
soup, type(soup)

# %%
links = soup.select('a[href]')

# %%
links

# %%
type(links)
# Out:
# list

# %%
html = "<html> <body> \
<h1 class='public_class_name' id='h1_id_name'>[1]크롤링이란?</h1> \
<p class='public_class_name' id='p01_id_name'>웹페이지에서 필요한 데이터를 추출하는 것</p> \
<p id='p02_id_name' align='center'>파이썬을 중심으로 다양한 웹크롤링 기술 발달</p> \
 </body> </html>"

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
title_data = soup.find_all('h1')

# %%
type(title_data)
# Out:
# bs4.element.ResultSet

# %%
title_data[0].string
# Out:
# '[1]크롤링이란?'

# %%
title_data[0]
# Out:
# <h1 class="public_class_name" id="h1_id_name">[1]크롤링이란?</h1>

# %%
title_data = soup.find_all(id = 'h1_id_name')

# %%
title_data[0].get_text()
# Out:
# '[1]크롤링이란?'

# %%
title_data[0].text
# Out:
# '[1]크롤링이란?'

# %%
# Out:
# []
